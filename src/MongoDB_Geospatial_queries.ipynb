# %% [markdown]
# ### Best Office Location:

# %%
import pandas as pd
import json

from geopy.distance import distance
from shapely.geometry import Point
import matplotlib.pyplot as plt

import cartoframes
from cartoframes.auth import set_default_credentials
from cartoframes.data.observatory import Enrichment
from cartoframes.data.services import Geocoding, Isolines
from cartoframes.viz import Map, Layer, color_continuous_style, size_continuous_style

# %% [markdown]
# Preparo cliente para poder hacer queries e ir filtrando el dataset.

# %%
from pymongo import MongoClient
client = MongoClient("mongodb://localhost/companies")
db = client.get_database()

# %% [markdown]
# Query a MongoDB de empresas que:
# - Se hayan creado hace 10 años o menos
# - Sigan existiendo
# - Dispongan de coordenadas en al menos una de sus oficinas
# - Hayan conseguido $1M de inversión o más

# %%
year=2010
filtro = {"$and": [{"founded_year":{'$gte':year}},
                   {"deadpooled_year":{"$eq":None}},
                   {"offices":{"$elemMatch":{"latitude":{"$ne":None}}}},
                   {"total_money_raised":{'$gte':"$1000000"}}]}

# Lista que cumple con la query:
new = list(db.companies.find(filtro, projection={"_id":0, "name":1, "offices":1, "founded_year":1}))

# Hago DataFrame de la lista:
new = pd.DataFrame(new)
print("Existen ", len(new), " empresas creadas después de " , year , " cuyas coordenadas están disponibles.")
new
# Out:
# Existen  32  empresas creadas después de  2010  cuyas coordenadas están disponibles.
#                      name  founded_year  \
# 0                   GENWI          2010
# 1                   Fixya          2013
# 2               Widgetbox          2012
# 3              RazorGator          2011
# 4   Social Gaming Network          2011
# 5                 Skydeck          2012
# 6                 Magento          2010
# 7                  Pixsta          2010
# 8             FirstString          2011
# 9            Titan Gaming          2010
# 10              Integrate          2010
# 11                 vufind          2010
# 12              travelmob          2011
# 13             UsingMiles          2010
# 14                  Kidos          2011
# 15              Integrate          2010
# 16                 vufind          2010
# 17              travelmob          2011
# 18             UsingMiles          2010
# 19                  Kidos          2011
# 20                  Yipit          2010
# 21                Queralt          2011
# 22              FeedHenry          2010
# 23               Tengaged          2010
# 24               VisualOn          2011
# 25            BASH Gaming          2010
# 26                AppNeta          2010
# 27                MyLikes          2010
# 28                Fliptop          2010
# 29              Chicisimo          2010
# 30  VistaGen Therapeutics          2013
# 31               ticketea          2010
#
#                                               offices
# 0   [{'description': '', 'address1': '4966 El Cami...
# 1   [{'description': '', 'address1': 'One Franklin...
# 2   [{'description': None, 'address1': None, 'addr...
# 3   [{'description': None, 'address1': '11150 Sant...
# 4   [{'description': 'HQ Los Angeles', 'address1':...
# 5   [{'description': '', 'address1': '330 Waverley...
# 6   [{'description': None, 'address1': '', 'addres...
# 7   [{'description': None, 'address1': '9 Thorpe C...
# 8   [{'description': None, 'address1': '', 'addres...
# 9   [{'description': 'Santa Monica Office', 'addre...
# 10  [{'description': 'Scottsdale HQ', 'address1': ...
# 11  [{'description': 'Headquarters', 'address1': '...
# 12  [{'description': 'HQ', 'address1': '71 Ayer Ra...
# 13  [{'description': 'Headquarters', 'address1': '...
# 14  [{'description': 'Mailing Address', 'address1'...
# 15  [{'description': 'Scottsdale HQ', 'address1': ...
# 16  [{'description': 'Headquarters', 'address1': '...
# 17  [{'description': 'HQ', 'address1': '71 Ayer Ra...
# 18  [{'description': 'Headquarters', 'address1': '...
# 19  [{'description': 'Mailing Address', 'address1'...
# 20  [{'description': 'HQ', 'address1': '3 W 18th',...
# 21  [{'description': '', 'address1': '250 State St...
# 22  [{'description': 'R&D Offices', 'address1': 'A...
# 23  [{'description': 'Main', 'address1': 'C/Pedrel...
# 24  [{'description': 'Headquarters', 'address1': '...
# 25  [{'description': 'US Office', 'address1': '', ...
# 26  [{'description': 'AppNeta', 'address1': '285 S...
# 27  [{'description': '', 'address1': '1000 Brannan...
# 28  [{'description': 'Headquarters', 'address1': '...
# 29  [{'description': 'Office', 'address1': 'Calle ...
# 30  [{'description': '', 'address1': '384 Oyster P...
# 31  [{'description': 'Office', 'address1': 'Marque...

# %% [markdown]
# Exploto el dataframe de modo que pueda tener latitud y longitud en columnas independientes:

# %%
a = new.explode("offices")
b = a[["offices"]].apply(lambda x: x.offices, result_type="expand", axis=1)
df_new = pd.concat([a,b], axis=1)

# Aumenta el número de registros puesto que algunas compañías tienen varias oficinas.
print(len(new), "--- VS ---" ,len(df_new))
df_new
# Out:
# 32 --- VS --- 43
#                      name  founded_year  \
# 0                   GENWI          2010
# 1                   Fixya          2013
# 2               Widgetbox          2012
# 3              RazorGator          2011
# 4   Social Gaming Network          2011
# 4   Social Gaming Network          2011
# 5                 Skydeck          2012
# 6                 Magento          2010
# 7                  Pixsta          2010
# 8             FirstString          2011
# 9            Titan Gaming          2010
# 10              Integrate          2010
# 10              Integrate          2010
# 10              Integrate          2010
# 10              Integrate          2010
# 11                 vufind          2010
# 12              travelmob          2011
# 13             UsingMiles          2010
# 14                  Kidos          2011
# 14                  Kidos          2011
# 15              Integrate          2010
# 15              Integrate          2010
# 15              Integrate          2010
# 15              Integrate          2010
# 16                 vufind          2010
# 17              travelmob          2011
# 18             UsingMiles          2010
# 19                  Kidos          2011
# 19                  Kidos          2011
# 20                  Yipit          2010
# 21                Queralt          2011
# 22              FeedHenry          2010
# 22              FeedHenry          2010
# 23               Tengaged          2010
# 24               VisualOn          2011
# 25            BASH Gaming          2010
# 25            BASH Gaming          2010
# 26                AppNeta          2010
# 27                MyLikes          2010
# 28                Fliptop          2010
# 29              Chicisimo          2010
# 30  VistaGen Therapeutics          2013
# 31               ticketea          2010
#
#                                               offices             description  \
# 0   {'description': '', 'address1': '4966 El Camin...
# 1   {'description': '', 'address1': 'One Franklin ...
# 2   {'description': None, 'address1': None, 'addre...                    None
# 3   {'description': None, 'address1': '11150 Santa...                    None
# 4   {'description': 'HQ Los Angeles', 'address1': ...          HQ Los Angeles
# 4   {'description': '', 'address1': '9606 S. Santa...
# 5   {'description': '', 'address1': '330 Waverley ...
# 6   {'description': None, 'address1': '', 'address...                    None
# 7   {'description': None, 'address1': '9 Thorpe Cl...                    None
# 8   {'description': None, 'address1': '', 'address...                    None
# 9   {'description': 'Santa Monica Office', 'addres...     Santa Monica Office
# 10  {'description': 'Scottsdale HQ', 'address1': '...           Scottsdale HQ
# 10  {'description': 'Colorado Office', 'address1':...         Colorado Office
# 10  {'description': 'San Francisco Office', 'addre...    San Francisco Office
# 10  {'description': 'Boston Office', 'address1': '...           Boston Office
# 11  {'description': 'Headquarters', 'address1': '1...            Headquarters
# 12  {'description': 'HQ', 'address1': '71 Ayer Raj...                      HQ
# 13  {'description': 'Headquarters', 'address1': '1...            Headquarters
# 14  {'description': 'Mailing Address', 'address1':...         Mailing Address
# 14  {'description': 'Corporate Headquarters', 'add...  Corporate Headquarters
# 15  {'description': 'Scottsdale HQ', 'address1': '...           Scottsdale HQ
# 15  {'description': 'Colorado Office', 'address1':...         Colorado Office
# 15  {'description': 'San Francisco Office', 'addre...    San Francisco Office
# 15  {'description': 'Boston Office', 'address1': '...           Boston Office
# 16  {'description': 'Headquarters', 'address1': '1...            Headquarters
# 17  {'description': 'HQ', 'address1': '71 Ayer Raj...                      HQ
# 18  {'description': 'Headquarters', 'address1': '1...            Headquarters
# 19  {'description': 'Mailing Address', 'address1':...         Mailing Address
# 19  {'description': 'Corporate Headquarters', 'add...  Corporate Headquarters
# 20  {'description': 'HQ', 'address1': '3 W 18th', ...                      HQ
# 21  {'description': '', 'address1': '250 State Str...
# 22  {'description': 'R&D Offices', 'address1': 'Ar...             R&D Offices
# 22  {'description': 'US Offices', 'address1': '15 ...              US Offices
# 23  {'description': 'Main', 'address1': 'C/Pedrell...                    Main
# 24  {'description': 'Headquarters', 'address1': '4...            Headquarters
# 25  {'description': 'US Office', 'address1': '', '...               US Office
# 25  {'description': 'India Office', 'address1': ''...            India Office
# 26  {'description': 'AppNeta', 'address1': '285 Su...                 AppNeta
# 27  {'description': '', 'address1': '1000 Brannan ...
# 28  {'description': 'Headquarters', 'address1': '5...            Headquarters
# 29  {'description': 'Office', 'address1': 'Calle H...                  Office
# 30  {'description': '', 'address1': '384 Oyster Po...
# 31  {'description': 'Office', 'address1': 'Marques...                  Office
#
#                                   address1                      address2  \
# 0                      4966 El Camino Real                     Suite 200
# 1                     One Franklin Parkway       Building 910, Suite 110
# 2                                     None                          None
# 3       11150 Santa Monica Blvd. Suite 500                          None
# 4              9570 W. Pico Blvd 3rd Floor
# 4                9606 S. Santa Monica Blvd                     2nd Floor
# 5                         330 Waverley St.                       Suite 3
# 6
# 7                           9 Thorpe Close                 Portobello Rd
# 8
# 9               1351 4th Street, 4th floor
# 10                 4900 N. Scottsdale Road                    Suite 4000
# 10                          1821 Blake St.                        STe 2A
# 10                             23 Geary St                    10th Floor
# 10                        239 South Street                     4th Floor
# 11         1290 oakmead parkway, suite 107
# 12                  71 Ayer Rajah Crescent                         06-20
# 13                           1514 Blake St
# 14               355 E. 72nd St., Suite 4E
# 14                        153 Roebling St.
# 15                 4900 N. Scottsdale Road                    Suite 4000
# 15                          1821 Blake St.                        STe 2A
# 15                             23 Geary St                    10th Floor
# 15                        239 South Street                     4th Floor
# 16         1290 oakmead parkway, suite 107
# 17                  71 Ayer Rajah Crescent                         06-20
# 18                           1514 Blake St
# 19               355 E. 72nd St., Suite 4E
# 19                        153 Roebling St.
# 20                                3 W 18th                     2nd Floor
# 21                        250 State Street                      Suite G1
# 22  ArcLabs Research & Innovation Building  WIT West Campus, Carriganore
# 22           15 New England Executive Park
# 23                               C/Pedrell
# 24                 4675 Stevens Creek Blvd                         # 200
# 25
# 25
# 26                       285 Summer Street                     4th Floor
# 27                   1000 Brannan St, #502
# 28                       580 Howard Street                     Suite 201
# 29                          Calle Henao 14                     nº 4, 4ºD
# 30        384 Oyster Point Blvd., Suite #8
# 31                         Marques de Lema                             7
#
#      zip_code                 city state_code country_code   latitude  \
# 0       94022            Los Altos         CA          USA  33.817100
# 1       94401            San Mateo         CA          USA  37.566879
# 2       94111        San Francisco         CA          USA  37.798853
# 3       90025          Los Angeles         CA          USA  34.047312
# 4       90035          Los Angeles         CA          USA  37.446823
# 4       90210        Beverly Hills         CA          USA  34.069849
# 5       94301            Palo Alto         CA          USA  37.564538
# 6                      Los Angeles         CA          USA  34.052187
# 7     W10 5XL               London       None          GBR  51.518190
# 8                      Los Angeles         CA          USA  34.052187
# 9       90401         Santa Monica         CA          USA  53.544711
# 10      85251           Scottsdale         AZ          USA  40.748104
# 10      80202               Denver         CO          USA        NaN
# 10      94104        San Francisco         CA          USA        NaN
# 10      01748            Hopkinton         MA          USA        NaN
# 11      94085            Sunnyvale         CA          USA  37.424614
# 12     139951            Singapore       None          SGP  21.303049
# 13      80202               Denver         CO          USA  39.749671
# 14      10021             New York         NY          USA  40.768058
# 14      11211             Brooklyn         NY          USA  40.714056
# 15      85251           Scottsdale         AZ          USA  40.748104
# 15      80202               Denver         CO          USA        NaN
# 15      94104        San Francisco         CA          USA        NaN
# 15      01748            Hopkinton         MA          USA        NaN
# 16      94085            Sunnyvale         CA          USA  37.424614
# 17     139951            Singapore       None          SGP  21.303049
# 18      80202               Denver         CO          USA  39.749671
# 19      10021             New York         NY          USA  40.768058
# 19      11211             Brooklyn         NY          USA  40.714056
# 20      10011             New York         NY          USA  40.744618
# 21      06473          North Haven         CT          USA  41.477864
# 22  Waterford            Waterford       None          IRL        NaN
# 22      01803           Burlington         MA          USA  42.485102
# 23      08032            Barcelona       None          ESP  41.424123
# 24      95051          Santa Clara         CA          USA  37.270518
# 25      94555              Fremont         CA          USA  37.556171
# 25                       Bangalore       None          IND  12.971606
# 26      02127         SOUTH BOSTON         MA          USA  42.318138
# 27      94103        San Francisco         CA          USA  37.777995
# 28      94105        San Francisco         CA          USA  37.775206
# 29                          Bilbao       None          ESP  43.264499
# 30      94080  South San Francisco         CA          USA  37.665648
# 31      28003               Madrid       None          ESP  40.445515
#
#      longitude
# 0  -111.903500
# 1  -122.323895
# 2  -122.398599
# 3  -118.445243
# 4  -122.161523
# 4  -118.405418
# 5  -122.325470
# 6  -118.243425
# 7    -0.208979
# 8  -118.243425
# 9  -113.515769
# 10  -74.035379
# 10         NaN
# 10         NaN
# 10         NaN
# 11 -122.145153
# 12 -157.789070
# 13 -104.999845
# 14  -73.956599
# 14  -73.957854
# 15  -74.035379
# 15         NaN
# 15         NaN
# 15         NaN
# 16 -122.145153
# 17 -157.789070
# 18 -104.999845
# 19  -73.956599
# 19  -73.957854
# 20  -73.987764
# 21  -72.819011
# 22         NaN
# 22  -71.208921
# 23    2.163425
# 24 -121.955879
# 25 -122.078063
# 25   77.594376
# 26  -71.247560
# 27 -122.408914
# 28 -122.419209
# 29   -2.930832
# 30 -122.384349
# 31   -3.706176

# %% [markdown]
# Elimino la columna offices y las filas duplicadas:

# %%
df = df_new.drop(columns=["offices"])

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Hay algunos registros que no tienen coordenadas pero sí direcciones postales.
# Puedo rellenar esos valores haciendo una request a la API de Google para que me devuelva coordenadas en base a direcciones.
# Para eso, primero hago una columna "Address" que contenga en un string la dirección completa para pasarla a la API.

# %%
df["Address"] = df.address1 + ", " + df.zip_code + ", " + df.city + ", " + df.country_code

# %%
df
# Out:
#                      name  founded_year             description  \
# 0                   GENWI          2010
# 1                   Fixya          2013
# 2               Widgetbox          2012                    None
# 3              RazorGator          2011                    None
# 4   Social Gaming Network          2011          HQ Los Angeles
# 4   Social Gaming Network          2011
# 5                 Skydeck          2012
# 6                 Magento          2010                    None
# 7                  Pixsta          2010                    None
# 8             FirstString          2011                    None
# 9            Titan Gaming          2010     Santa Monica Office
# 10              Integrate          2010           Scottsdale HQ
# 10              Integrate          2010         Colorado Office
# 10              Integrate          2010    San Francisco Office
# 10              Integrate          2010           Boston Office
# 11                 vufind          2010            Headquarters
# 12              travelmob          2011                      HQ
# 13             UsingMiles          2010            Headquarters
# 14                  Kidos          2011         Mailing Address
# 14                  Kidos          2011  Corporate Headquarters
# 20                  Yipit          2010                      HQ
# 21                Queralt          2011
# 22              FeedHenry          2010             R&D Offices
# 22              FeedHenry          2010              US Offices
# 23               Tengaged          2010                    Main
# 24               VisualOn          2011            Headquarters
# 25            BASH Gaming          2010               US Office
# 25            BASH Gaming          2010            India Office
# 26                AppNeta          2010                 AppNeta
# 27                MyLikes          2010
# 28                Fliptop          2010            Headquarters
# 29              Chicisimo          2010                  Office
# 30  VistaGen Therapeutics          2013
# 31               ticketea          2010                  Office
#
#                                   address1                      address2  \
# 0                      4966 El Camino Real                     Suite 200
# 1                     One Franklin Parkway       Building 910, Suite 110
# 2                                     None                          None
# 3       11150 Santa Monica Blvd. Suite 500                          None
# 4              9570 W. Pico Blvd 3rd Floor
# 4                9606 S. Santa Monica Blvd                     2nd Floor
# 5                         330 Waverley St.                       Suite 3
# 6
# 7                           9 Thorpe Close                 Portobello Rd
# 8
# 9               1351 4th Street, 4th floor
# 10                 4900 N. Scottsdale Road                    Suite 4000
# 10                          1821 Blake St.                        STe 2A
# 10                             23 Geary St                    10th Floor
# 10                        239 South Street                     4th Floor
# 11         1290 oakmead parkway, suite 107
# 12                  71 Ayer Rajah Crescent                         06-20
# 13                           1514 Blake St
# 14               355 E. 72nd St., Suite 4E
# 14                        153 Roebling St.
# 20                                3 W 18th                     2nd Floor
# 21                        250 State Street                      Suite G1
# 22  ArcLabs Research & Innovation Building  WIT West Campus, Carriganore
# 22           15 New England Executive Park
# 23                               C/Pedrell
# 24                 4675 Stevens Creek Blvd                         # 200
# 25
# 25
# 26                       285 Summer Street                     4th Floor
# 27                   1000 Brannan St, #502
# 28                       580 Howard Street                     Suite 201
# 29                          Calle Henao 14                     nº 4, 4ºD
# 30        384 Oyster Point Blvd., Suite #8
# 31                         Marques de Lema                             7
#
#      zip_code                 city state_code country_code   latitude  \
# 0       94022            Los Altos         CA          USA  33.817100
# 1       94401            San Mateo         CA          USA  37.566879
# 2       94111        San Francisco         CA          USA  37.798853
# 3       90025          Los Angeles         CA          USA  34.047312
# 4       90035          Los Angeles         CA          USA  37.446823
# 4       90210        Beverly Hills         CA          USA  34.069849
# 5       94301            Palo Alto         CA          USA  37.564538
# 6                      Los Angeles         CA          USA  34.052187
# 7     W10 5XL               London       None          GBR  51.518190
# 8                      Los Angeles         CA          USA  34.052187
# 9       90401         Santa Monica         CA          USA  53.544711
# 10      85251           Scottsdale         AZ          USA  40.748104
# 10      80202               Denver         CO          USA        NaN
# 10      94104        San Francisco         CA          USA        NaN
# 10      01748            Hopkinton         MA          USA        NaN
# 11      94085            Sunnyvale         CA          USA  37.424614
# 12     139951            Singapore       None          SGP  21.303049
# 13      80202               Denver         CO          USA  39.749671
# 14      10021             New York         NY          USA  40.768058
# 14      11211             Brooklyn         NY          USA  40.714056
# 20      10011             New York         NY          USA  40.744618
# 21      06473          North Haven         CT          USA  41.477864
# 22  Waterford            Waterford       None          IRL        NaN
# 22      01803           Burlington         MA          USA  42.485102
# 23      08032            Barcelona       None          ESP  41.424123
# 24      95051          Santa Clara         CA          USA  37.270518
# 25      94555              Fremont         CA          USA  37.556171
# 25                       Bangalore       None          IND  12.971606
# 26      02127         SOUTH BOSTON         MA          USA  42.318138
# 27      94103        San Francisco         CA          USA  37.777995
# 28      94105        San Francisco         CA          USA  37.775206
# 29                          Bilbao       None          ESP  43.264499
# 30      94080  South San Francisco         CA          USA  37.665648
# 31      28003               Madrid       None          ESP  40.445515
#
#      longitude                                            Address
# 0  -111.903500         4966 El Camino Real, 94022, Los Altos, USA
# 1  -122.323895        One Franklin Parkway, 94401, San Mateo, USA
# 2  -122.398599                                                NaN
# 3  -118.445243  11150 Santa Monica Blvd. Suite 500, 90025, Los...
# 4  -122.161523  9570 W. Pico Blvd 3rd Floor, 90035, Los Angele...
# 4  -118.405418  9606 S. Santa Monica Blvd, 90210, Beverly Hill...
# 5  -122.325470            330 Waverley St., 94301, Palo Alto, USA
# 6  -118.243425                               , , Los Angeles, USA
# 7    -0.208979               9 Thorpe Close, W10 5XL, London, GBR
# 8  -118.243425                               , , Los Angeles, USA
# 9  -113.515769  1351 4th Street, 4th floor, 90401, Santa Monic...
# 10  -74.035379    4900 N. Scottsdale Road, 85251, Scottsdale, USA
# 10         NaN                 1821 Blake St., 80202, Denver, USA
# 10         NaN             23 Geary St, 94104, San Francisco, USA
# 10         NaN            239 South Street, 01748, Hopkinton, USA
# 11 -122.145153  1290 oakmead parkway, suite 107, 94085, Sunnyv...
# 12 -157.789070     71 Ayer Rajah Crescent, 139951, Singapore, SGP
# 13 -104.999845                  1514 Blake St, 80202, Denver, USA
# 14  -73.956599    355 E. 72nd St., Suite 4E, 10021, New York, USA
# 14  -73.957854             153 Roebling St., 11211, Brooklyn, USA
# 20  -73.987764                     3 W 18th, 10011, New York, USA
# 21  -72.819011          250 State Street, 06473, North Haven, USA
# 22         NaN  ArcLabs Research & Innovation Building, Waterf...
# 22  -71.208921  15 New England Executive Park, 01803, Burlingt...
# 23    2.163425                   C/Pedrell, 08032, Barcelona, ESP
# 24 -121.955879   4675 Stevens Creek Blvd, 95051, Santa Clara, USA
# 25 -122.078063                              , 94555, Fremont, USA
# 25   77.594376                                 , , Bangalore, IND
# 26  -71.247560        285 Summer Street, 02127, SOUTH BOSTON, USA
# 27 -122.408914   1000 Brannan St, #502, 94103, San Francisco, USA
# 28 -122.419209       580 Howard Street, 94105, San Francisco, USA
# 29   -2.930832                      Calle Henao 14, , Bilbao, ESP
# 30 -122.384349  384 Oyster Point Blvd., Suite #8, 94080, South...
# 31   -3.706176                Marques de Lema, 28003, Madrid, ESP

# %% [markdown]
# Esto es una alternativa a la API de Google, pero el servicio no está disponible temporalmente:

# %%
from time import sleep 
import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim

def coord(x):
    sleep(1)
    geolocator = Nominatim(user_agent = "myGeocoder")
    location = geolocator.geocode(x)
    if location == None:
        return "not possible"
    else:
        return (location.latitude, location.longitude)

# %% [markdown]
# Request a la API de Google:

# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv()
gooKey = os.getenv("GoogleAPIKey")
apikey = gooKey

def getCoord(address):
    key = apikey
    url = f'https://maps.googleapis.com/maps/api/geocode/json?address={address}&key={key}'
    response = requests.get(url)
    data = response.json()
    return data
    # me devuelve un diccionario

# %% [markdown]
# Hago la request a la API para los casos en los que las coordenadas sean NaN:

# %%
data = df[df["latitude"].isna()]["Address"].apply(getCoord)

# %% [markdown]
# Compruebo los resultados:
# - Me devulve 3 correctos.
# - El erróneo es debido seguramente al caracter "&" puesto que si elimino esa parte del string, me devuelve las coordenadas correctas.

# %%
data
# Out:
# 10    {'results': [{'address_components': [{'long_na...
# 10    {'results': [{'address_components': [{'long_na...
# 10    {'results': [{'address_components': [{'long_na...
# 22            {'results': [], 'status': 'ZERO_RESULTS'}
# Name: Address, dtype: object

# %% [markdown]
# Con la función **cleanCoord** accedo a la parta del json que contiene las coordenadas:

# %%
def cleanCoord(x):
    print(type(x))
    latGoo = x['results'][0]['geometry']['location']['lat']
    lngGoo = x['results'][0]['geometry']['location']['lng']
    return (latGoo, lngGoo)

# %%
valores = data[:-1].apply(cleanCoord)
valores = list(valores)
print(valores)
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# [(39.752908, -104.9965953), (37.78775419999999, -122.4040147), (42.1900278, -71.53822339999999)]

# %% [markdown]
# - Para evitar **"index out of range"**, prescindo del último elemento de la lista y relleno los NaN con los nuevos valores.
# - Compruebo con un print qué **"Address"** aún sigue teniendo coordenadas NaN.
# - Podría volver a hacer una request a la API modificando el string, pero continúo.

# %%
addresses = list(df[df["latitude"].isna()]["Address"])
addr = addresses[:-1]

i=0
for a in addr:
    df.loc[df['Address'] == a,"latitude"] = valores[i][0]
    df.loc[df['Address'] == a,"longitude"] = valores[i][1]
    i+=1
    
print(addresses)
# Out:
# ['ArcLabs Research & Innovation Building, Waterford, Waterford, IRL']

# %%
df2 = df

# %% [markdown]
# Para poder continuar con un DataFrame limpio, elimino la fila con latitud = longitud = NaN

# %%
df2.dropna(subset=["latitude","longitude"], inplace=True)

# %%
df2
# Out:
#                      name  founded_year             description  \
# 0                   GENWI          2010
# 1                   Fixya          2013
# 2               Widgetbox          2012                    None
# 3              RazorGator          2011                    None
# 4   Social Gaming Network          2011          HQ Los Angeles
# 4   Social Gaming Network          2011
# 5                 Skydeck          2012
# 6                 Magento          2010                    None
# 7                  Pixsta          2010                    None
# 8             FirstString          2011                    None
# 9            Titan Gaming          2010     Santa Monica Office
# 10              Integrate          2010           Scottsdale HQ
# 10              Integrate          2010         Colorado Office
# 10              Integrate          2010    San Francisco Office
# 10              Integrate          2010           Boston Office
# 11                 vufind          2010            Headquarters
# 12              travelmob          2011                      HQ
# 13             UsingMiles          2010            Headquarters
# 14                  Kidos          2011         Mailing Address
# 14                  Kidos          2011  Corporate Headquarters
# 20                  Yipit          2010                      HQ
# 21                Queralt          2011
# 22              FeedHenry          2010              US Offices
# 23               Tengaged          2010                    Main
# 24               VisualOn          2011            Headquarters
# 25            BASH Gaming          2010               US Office
# 25            BASH Gaming          2010            India Office
# 26                AppNeta          2010                 AppNeta
# 27                MyLikes          2010
# 28                Fliptop          2010            Headquarters
# 29              Chicisimo          2010                  Office
# 30  VistaGen Therapeutics          2013
# 31               ticketea          2010                  Office
#
#                               address1                 address2 zip_code  \
# 0                  4966 El Camino Real                Suite 200    94022
# 1                 One Franklin Parkway  Building 910, Suite 110    94401
# 2                                 None                     None    94111
# 3   11150 Santa Monica Blvd. Suite 500                     None    90025
# 4          9570 W. Pico Blvd 3rd Floor                             90035
# 4            9606 S. Santa Monica Blvd                2nd Floor    90210
# 5                     330 Waverley St.                  Suite 3    94301
# 6
# 7                       9 Thorpe Close            Portobello Rd  W10 5XL
# 8
# 9           1351 4th Street, 4th floor                             90401
# 10             4900 N. Scottsdale Road               Suite 4000    85251
# 10                      1821 Blake St.                   STe 2A    80202
# 10                         23 Geary St               10th Floor    94104
# 10                    239 South Street                4th Floor    01748
# 11     1290 oakmead parkway, suite 107                             94085
# 12              71 Ayer Rajah Crescent                    06-20   139951
# 13                       1514 Blake St                             80202
# 14           355 E. 72nd St., Suite 4E                             10021
# 14                    153 Roebling St.                             11211
# 20                            3 W 18th                2nd Floor    10011
# 21                    250 State Street                 Suite G1    06473
# 22       15 New England Executive Park                             01803
# 23                           C/Pedrell                             08032
# 24             4675 Stevens Creek Blvd                    # 200    95051
# 25                                                                 94555
# 25
# 26                   285 Summer Street                4th Floor    02127
# 27               1000 Brannan St, #502                             94103
# 28                   580 Howard Street                Suite 201    94105
# 29                      Calle Henao 14                nº 4, 4ºD
# 30    384 Oyster Point Blvd., Suite #8                             94080
# 31                     Marques de Lema                        7    28003
#
#                    city state_code country_code   latitude   longitude  \
# 0             Los Altos         CA          USA  33.817100 -111.903500
# 1             San Mateo         CA          USA  37.566879 -122.323895
# 2         San Francisco         CA          USA  37.798853 -122.398599
# 3           Los Angeles         CA          USA  34.047312 -118.445243
# 4           Los Angeles         CA          USA  37.446823 -122.161523
# 4         Beverly Hills         CA          USA  34.069849 -118.405418
# 5             Palo Alto         CA          USA  37.564538 -122.325470
# 6           Los Angeles         CA          USA  34.052187 -118.243425
# 7                London       None          GBR  51.518190   -0.208979
# 8           Los Angeles         CA          USA  34.052187 -118.243425
# 9          Santa Monica         CA          USA  53.544711 -113.515769
# 10           Scottsdale         AZ          USA  40.748104  -74.035379
# 10               Denver         CO          USA  39.752908 -104.996595
# 10        San Francisco         CA          USA  37.787754 -122.404015
# 10            Hopkinton         MA          USA  42.190028  -71.538223
# 11            Sunnyvale         CA          USA  37.424614 -122.145153
# 12            Singapore       None          SGP  21.303049 -157.789070
# 13               Denver         CO          USA  39.749671 -104.999845
# 14             New York         NY          USA  40.768058  -73.956599
# 14             Brooklyn         NY          USA  40.714056  -73.957854
# 20             New York         NY          USA  40.744618  -73.987764
# 21          North Haven         CT          USA  41.477864  -72.819011
# 22           Burlington         MA          USA  42.485102  -71.208921
# 23            Barcelona       None          ESP  41.424123    2.163425
# 24          Santa Clara         CA          USA  37.270518 -121.955879
# 25              Fremont         CA          USA  37.556171 -122.078063
# 25            Bangalore       None          IND  12.971606   77.594376
# 26         SOUTH BOSTON         MA          USA  42.318138  -71.247560
# 27        San Francisco         CA          USA  37.777995 -122.408914
# 28        San Francisco         CA          USA  37.775206 -122.419209
# 29               Bilbao       None          ESP  43.264499   -2.930832
# 30  South San Francisco         CA          USA  37.665648 -122.384349
# 31               Madrid       None          ESP  40.445515   -3.706176
#
#                                               Address
# 0          4966 El Camino Real, 94022, Los Altos, USA
# 1         One Franklin Parkway, 94401, San Mateo, USA
# 2                                                 NaN
# 3   11150 Santa Monica Blvd. Suite 500, 90025, Los...
# 4   9570 W. Pico Blvd 3rd Floor, 90035, Los Angele...
# 4   9606 S. Santa Monica Blvd, 90210, Beverly Hill...
# 5             330 Waverley St., 94301, Palo Alto, USA
# 6                                , , Los Angeles, USA
# 7                9 Thorpe Close, W10 5XL, London, GBR
# 8                                , , Los Angeles, USA
# 9   1351 4th Street, 4th floor, 90401, Santa Monic...
# 10    4900 N. Scottsdale Road, 85251, Scottsdale, USA
# 10                 1821 Blake St., 80202, Denver, USA
# 10             23 Geary St, 94104, San Francisco, USA
# 10            239 South Street, 01748, Hopkinton, USA
# 11  1290 oakmead parkway, suite 107, 94085, Sunnyv...
# 12     71 Ayer Rajah Crescent, 139951, Singapore, SGP
# 13                  1514 Blake St, 80202, Denver, USA
# 14    355 E. 72nd St., Suite 4E, 10021, New York, USA
# 14             153 Roebling St., 11211, Brooklyn, USA
# 20                     3 W 18th, 10011, New York, USA
# 21          250 State Street, 06473, North Haven, USA
# 22  15 New England Executive Park, 01803, Burlingt...
# 23                   C/Pedrell, 08032, Barcelona, ESP
# 24   4675 Stevens Creek Blvd, 95051, Santa Clara, USA
# 25                              , 94555, Fremont, USA
# 25                                 , , Bangalore, IND
# 26        285 Summer Street, 02127, SOUTH BOSTON, USA
# 27   1000 Brannan St, #502, 94103, San Francisco, USA
# 28       580 Howard Street, 94105, San Francisco, USA
# 29                      Calle Henao 14, , Bilbao, ESP
# 30  384 Oyster Point Blvd., Suite #8, 94080, South...
# 31                Marques de Lema, 28003, Madrid, ESP

# %%
df3 = df2.to_json("../output/test2.json", orient = "records")

# %%
import geopandas as gpd

gdf = gpd.GeoDataFrame(df3, geometry = gpd.points_from_xy(df.longitude, df.latitude))
l2 = gdf
print(f'Tipo: {type(gdf)}')
l2
# Out:
# Tipo: <class 'geopandas.geodataframe.GeoDataFrame'>
#                        geometry
# 0   POINT (-111.90350 33.81710)
# 1   POINT (-122.32389 37.56688)
# 2   POINT (-122.39860 37.79885)
# 3   POINT (-118.44524 34.04731)
# 4   POINT (-122.16152 37.44682)
# 5   POINT (-118.40542 34.06985)
# 6   POINT (-122.32547 37.56454)
# 7   POINT (-118.24343 34.05219)
# 8     POINT (-0.20898 51.51819)
# 9   POINT (-118.24343 34.05219)
# 10  POINT (-113.51577 53.54471)
# 11   POINT (-74.03538 40.74810)
# 12  POINT (-104.99660 39.75291)
# 13  POINT (-122.40401 37.78775)
# 14   POINT (-71.53822 42.19003)
# 15  POINT (-122.14515 37.42461)
# 16  POINT (-157.78907 21.30305)
# 17  POINT (-104.99984 39.74967)
# 18   POINT (-73.95660 40.76806)
# 19   POINT (-73.95785 40.71406)
# 20   POINT (-73.98776 40.74462)
# 21   POINT (-72.81901 41.47786)
# 22   POINT (-71.20892 42.48510)
# 23     POINT (2.16342 41.42412)
# 24  POINT (-121.95588 37.27052)
# 25  POINT (-122.07806 37.55617)
# 26    POINT (77.59438 12.97161)
# 27   POINT (-71.24756 42.31814)
# 28  POINT (-122.40891 37.77799)
# 29  POINT (-122.41921 37.77521)
# 30    POINT (-2.93083 43.26450)
# 31  POINT (-122.38435 37.66565)
# 32    POINT (-3.70618 40.44552)

# %% [markdown]
# Mapa de Carto con los puntos del geoDataFrame:

# %%
Map(Layer(l2))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.2/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.2/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.2/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.2/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.2/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <p>There is a <span class=&quot;errors&quot; id=&quot;error-highlight&quot;></span>
#   from the <a href=&quot;https://carto.com/developers/carto-vl/&quot; target=&quot;_blank&quot;>CARTO VL</a> library:</p>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {
#       // throw out eval line/column and use top-most line/column number
#       parts[2] = submatch[1]; // url
#       parts[3] = submatch[2]; // line
#       parts[4] = submatch[3]; // column
#     }
#
#     return {
#       file: !isNative ? parts[2] : null,
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: isNative ? [parts[2]] : [],
#       lineNumber: parts[3] ? +parts[3] : null,
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseWinjs(line) {
#     const parts = winjsRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     return {
#       file: parts[2],
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: [],
#       lineNumber: +parts[3],
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseGecko(line) {
#     const parts = geckoRe.exec(l

# %% [markdown]
# Request a la API de FourSquare:

# %%
import json, requests

FourSquareID = os.getenv("FSID")
fsID = FourSquareID

FourSquareKEY = os.getenv("FSKEY")
fsKEY = FourSquareKEY

url = 'https://api.foursquare.com/v2/venues/search'
params = dict(
  client_id='fsID',
  client_secret='fsKEY',
  v='20200211',
  ll='40.7243,-74.0018',
  query='airport',
  limit=1
)
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)
